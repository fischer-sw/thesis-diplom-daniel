# %% [markdown]
# # Notebook to quickly look at mesh data from paramerter table

# %%
# imports
import re
import sys
import os
import glob
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# Read data from file

# %%
path = os.path.join(sys.path[0], "..", "ansys", "mesh_size_data")
files = glob.glob("*csv", root_dir=path)

def read_data(file_name):
    if file_name in files:
        data_path = os.path.join(path, file_name)


        with open(data_path) as f:
            tmp = f.readlines()
        header = tmp[3]

        tmp_header = header.split("- ")
        tmp_header_list = ["name"]
        for ele in tmp_header:
            element = ele.split(",")[0].split("\n")[0]
            tmp_header_list.append(element)
        tmp_header_list.remove(tmp_header_list[0])
        new_cols = tmp_header_list

        data = pd.read_csv(data_path, skiprows=6)

        old_cols = list(data.columns)
        cols = {}
        for idx, ele in enumerate(old_cols):
            cols[ele] = new_cols[idx]

        data.rename(columns=cols, inplace=True)
        
       
        data["Cells"] = data[new_cols[1]] * data[new_cols[2]] 

    else:
        print(f"No file {file_name} in directory. files are {files}")
    return data

def plot_data(data, n_inputs):

    out_vars = list(data.columns)[n_inputs+1:-1]
    print(out_vars)
    for ele in out_vars:
        fig, axs = plt.subplots(1, 1, figsize=(6.5,2.4))
        plt.plot(data["Cells"], data[ele],'bo')
        # plt.plot(data["Edge Sizing 2 Number of Divisions"], data[ele],'bo')

        plt.title(ele)
        plt.xlabel("Divisions")

# %% [markdown]
# Read data and show table

# %%
data = read_data("mesh_data_h.csv")
data
# Out:
#        #   Edge Sizing Number of Divisions  Edge Sizing 2 Number of Divisions  \
# 0    DP 0                              500                                 30
# 1    DP 1                              500                                 60
# 2    DP 2                              500                                 80
# 3    DP 3                              500                                 40
# 4    DP 4                              500                                 50
# 5    DP 5                              500                                 70
# 6    DP 6                              500                                 30
# 7    DP 7                              500                                 10
# 8    DP 8                              500                                 30
# 9    DP 9                              500                                 20
# 10  DP 10                              500                                 30
# 11  DP 11                              500                                100
#
#     Inflation Maximum Layers  wall_shear_max-op [Pa]  wall_shear_min-op [Pa]  \
# 0                          2                0.001465            1.130625e-09
# 1                          2                0.001474            2.611754e-09
# 2                          2                0.001510            1.976905e-10
# 3                          2                0.001473            2.694405e-09
# 4                          2                0.001471            3.512088e-09
# 5                          2                0.001496            1.462317e-09
# 6                          2                0.001465            1.130625e-09
# 7                          2                0.001457            2.909374e-10
# 8                          2                0.001465            1.130625e-09
# 9                          2                0.001458            2.186552e-09
# 10                         2                0.001465            1.130625e-09
# 11                         2                0.001522            5.354000e-09
#
#     wall_shear_avg-op [Pa]  Cells
# 0                 0.000006  15000
# 1                 0.000006  30000
# 2                 0.000006  40000
# 3                 0.000006  20000
# 4                 0.000006  25000
# 5                 0.000006  35000
# 6                 0.000006  15000
# 7                 0.000005   5000
# 8                 0.000006  15000
# 9                 0.000006  10000
# 10                0.000006  15000
# 11                0.000006  50000

# %% [markdown]
# show diagrams

# %%
plot_data(data, 3)
# Out:
# ['wall_shear_max-op [Pa]', 'wall_shear_min-op [Pa]', 'wall_shear_avg-op [Pa]']

# %%
data = read_data("mesh_data_r.csv")
data
# Out:
#        #   Edge Sizing Number of Divisions  Edge Sizing 2 Number of Divisions  \
# 0    DP 0                              150                                 40
# 1    DP 7                              350                                 40
# 2    DP 8                              500                                 40
# 3    DP 9                             1000                                 40
# 4   DP 10                             1500                                 40
# 5   DP 11                             2000                                 40
# 6   DP 12                             2500                                 40
# 7   DP 13                             3000                                 40
# 8   DP 14                             5000                                 40
# 9   DP 15                              750                                 40
# 10  DP 16                             1750                                 40
# 11  DP 17                             1250                                 40
#
#     Inflation Maximum Layers  wall_shear_max-op [Pa]  wall_shear_min-op [Pa]  \
# 0                          2                0.000574            3.377605e-08
# 1                          2                0.001118            1.611927e-09
# 2                          2                0.001474            6.610493e-09
# 3                          2                0.002449            2.148180e-09
# 4                          2                0.003289            1.843621e-09
# 5                          2                0.004098            1.440242e-10
# 6                          2                0.004880            2.062170e-10
# 7                          2                0.005665            1.161249e-09
# 8                          2                0.008731            1.235324e-09
# 9                          2                0.001991            2.769158e-09
# 10                         2                0.003701            2.767184e-09
# 11                         2                0.002880            2.528793e-09
#
#     wall_shear_avg-op [Pa]   Cells
# 0                 0.000005    6000
# 1                 0.000006   14000
# 2                 0.000006   20000
# 3                 0.000007   40000
# 4                 0.000007   60000
# 5                 0.000007   80000
# 6                 0.000008  100000
# 7                 0.000008  120000
# 8                 0.000008  200000
# 9                 0.000007   30000
# 10                0.000007   70000
# 11                0.000007   50000

# %%
plot_data(data, 3)
# Out:
# ['wall_shear_max-op [Pa]', 'wall_shear_min-op [Pa]', 'wall_shear_avg-op [Pa]']
